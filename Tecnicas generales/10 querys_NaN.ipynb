# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavovazquez/ML/blob/main/ML_querys_NaN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uso de `df.query()` para Filtrar Filas y Columnas en Pandas
#
# El método `df.query()` permite filtrar filas y columnas de un **DataFrame de Pandas** utilizando expresiones lógicas de manera más compacta y legible.
#
# En este notebook, aprenderemos a usar `df.query()` para filtrar datos con **condiciones lógicas** y **manejo de valores nulos (`NaN`)**.
#
# ## **1. Creación de un DataFrame de Ejemplo**

# %%
import pandas as pd
import numpy as np

# Crear un DataFrame con datos ficticios
df = pd.DataFrame({
    "Nombre": ["Ana", "Juan", "Luis", "Marta", "Pedro", "Sofia"],
    "Edad": [25, 30, 35, 40, 22, np.nan],
    "Salario": [50000, 54000, 58000, np.nan, 51000, 49000],
    "Departamento": ["Ventas", "IT", "IT", "RRHH", "Ventas", "IT"],
    "Años_Experiencia": [3, 7, 10, 5, np.nan, 6]
})

# Mostrar el DataFrame
print(df.shape)
df
# Out:
# (6, 5)
#   Nombre  Edad  Salario Departamento  Años_Experiencia
# 0    Ana  25.0  50000.0       Ventas               3.0
# 1   Juan  30.0  54000.0           IT               7.0
# 2   Luis  35.0  58000.0           IT              10.0
# 3  Marta  40.0      NaN         RRHH               5.0
# 4  Pedro  22.0  51000.0       Ventas               NaN
# 5  Sofia   NaN  49000.0           IT               6.0

# %% [markdown]
# ## **2. Filtrar Filas Usando Condiciones Lógicas**
#
# ### **2.1 Filtrar por Igualdad (`==`)**
# ```python
# df.query("Departamento == 'IT'")
# ```
#
# ### **2.2 Filtrar por Diferencia (`!=`)**
# ```python
# df.query("Departamento != 'IT'")
# ```
#
# ### **2.3 Filtrar por Mayor (`>`) y Menor (`<`)**
# ```python
# df.query("Edad > 30")
# df.query("Salario < 55000")
# ```
#
# ### **Ejemplo en Python**

# %%
# Filtrar empleados del departamento IT
df.query("Departamento == 'IT'")
# Out:
#   Nombre  Edad  Salario Departamento  Años_Experiencia
# 1   Juan  30.0  54000.0           IT               7.0
# 2   Luis  35.0  58000.0           IT              10.0
# 5  Sofia   NaN  49000.0           IT               6.0

# %% [markdown]
# ## **3. Filtrar con Múltiples Condiciones**
#
# Podemos combinar condiciones usando **operadores lógicos**:
#
# - **AND (`&`)** → Ambas condiciones deben cumplirse.
# - **OR (`|`)** → Basta con que una condición sea verdadera.
#
# ### **3.1 Filtrar empleados de IT con salario mayor a 50000**
# ```python
# df.query("Departamento == 'IT' & Salario > 50000")
# ```
#
# ### **3.2 Filtrar empleados de Ventas o RRHH**
# ```python
# df.query("Departamento == 'Ventas' | Departamento == 'RRHH'")
# ```
#
# ### **Ejemplo en Python**

# %%
# Filtrar empleados del departamento IT con salario mayor a 50000
df.query("Departamento == 'IT'" )
# Out:
#   Nombre  Edad  Salario Departamento  Años_Experiencia
# 1   Juan  30.0  54000.0           IT               7.0
# 2   Luis  35.0  58000.0           IT              10.0
# 5  Sofia   NaN  49000.0           IT               6.0

# %% [markdown]
# ## **4. Manejo de Valores Nulos (`NaN`) con `query()`**
#
# En `df.query()`, podemos filtrar filas que **tengan o no tengan valores nulos** en ciertas columnas.
#
# ### **4.1 Filtrar filas donde una columna NO tiene `NaN`**
# ```python
# df.query("Salario.notnull()")
# ```
#
# ### **4.2 Filtrar filas donde una columna SÍ tiene `NaN`**
# ```python
# df.query("Edad.isnull()")
# ```
#
# ### **Ejemplo en Python**

# %%
# Filtrar empleados que tienen salario NO nulo
df.query("Salario.notnull()").shape
# Out:
# (5, 5)

# %% [markdown]
# ## **5. Filtrar y Seleccionar Columnas Específicas**
#
# Podemos combinar `df.query()` con `filter` o `loc` para extraer ciertas columnas después de aplicar un filtro.
#
# ### **5.1 Filtrar y seleccionar solo las columnas "Nombre" y "Salario"**
# ```python
# df.query("Edad > 30")[["Nombre", "Salario"]]
# ```
#
# ### **5.2 Filtrar y seleccionar columnas que contienen "Salario" en el nombre**
# ```python
# df.filter(like="Salario", axis=1)
# ```
#
# ### **Ejemplo en Python**

# %%
# Filtrar empleados mayores de 30 años y mostrar solo Nombre y Salario
df.query("Edad > 30")[["Nombre", "Salario"]]
# Out:
#   Nombre  Salario
# 2   Luis  58000.0
# 3  Marta      NaN

# %% [markdown]
# # 6. NaN
#
# ### ¿Qué es un NaN en Pandas?
#
# En Pandas, los valores faltantes o desconocidos se representan con NaN, que significa "Not a Number".
#
# - NaN no es lo mismo que cero (0) ni que una cadena vacía ("").
#
# - NaN indica que el dato está faltante, incompleto o no disponible.
#
# Es muy común encontrar NaN en datasets reales, por ejemplo cuando un empleado no informó su salario o cuando un sensor no registró un valor.
#
# En Pandas, muchas funciones están diseñadas para detectar y trabajar con estos valores. Por ejemplo:
# ```
# df.isnull()     # Devuelve True si el valor es NaN
# df.notnull()    # Devuelve True si el valor NO es NaN
# df.dropna()     # Elimina filas con NaN
# df.fillna(0)    # Reemplaza los NaN por el valor 0
# ```

# %% [markdown]
# ### Reemplazar valores del DataFrame por NaN
# En algunos datasets, el valor 0 (u otro) representa un dato faltante más que un valor real. Para tratarlos como valores nulos (NaN), podemos reemplazarlos.
#
# ```
# df_replace = df.replace(0, np.nan)
# df_replace
# ```
#
# Ejemplo: Reemplazar solo en columnas específicas
# ```
# df_replace = df.copy()
# df_replace[["Edad", "Años_Experiencia"]] = df_replace[["Edad", "Años_Experiencia"]].replace(0, np.nan)
# df_replace
# ```
#
#
# Con esto, todos los ceros en esas columnas se transforman en NaN, y luego se pueden manejar con las funciones de Pandas para valores nulos.
#
# ### Eliminar Filas con Valores NaN
#
# Muchas veces no queremos trabajar con filas incompletas. En esos casos, podemos eliminar las filas que contienen un dato NaN (también se podrían imputar sus valores).
#
# ```
# df_sin_nan = df.dropna()
# df_sin_nan
# ```
